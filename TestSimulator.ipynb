# %%
from crowd_nav.configs.config import ConfigNoArgs
from crowd_sim.envs import CrowdSim, CrowdSimVarNum

# %%
config = ConfigNoArgs()
env = CrowdSimVarNum()
env.configure(config)
env.thisSeed=0
env.nenv=1
# Out:
# /Users/kxu/mambaforge/envs/scenicgym/lib/python3.10/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
env.reset()
# Out:
# {'robot_node': [-3.5774414469037055,
#   -4.672769958556648,
#   0.3,
#   0.3306811354858348,
#   4.411863948134,
#   1,
#   1.5707963267948966],
#  'temporal_edges': array([0, 0]),
#  'visible_masks': array([ True,  True,  True,  True,  True,  True,  True,  True, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False]),
#  'spatial_edges': array([[-1.48322967,  0.07608847],
#         [-1.4710778 ,  1.45883757],
#         [ 0.19976301, -2.25808689],
#         [ 1.66467063, -1.8430228 ],
#         [ 3.79823594, -2.40259109],
#         [ 4.80828387, -1.97152912],
#         [-3.60960977,  3.86629443],
#         [ 4.0375009 , -3.54171088],
#         [15.        , 15.        ],
#         [15.        , 15.        ],
#         [15.        , 15.        ],
#         [15.        , 15.        ],
#         [15.        , 15.        ],
#         [15.        , 15.        ],
#         [15.        , 15.        ],
#         [15.        , 15.        ],
#         [15.        , 15.        ],
#         [15.        , 15.        ],
#         [15.        , 15.        ],
#         [15.        , 15.        ]]),
#  'detected_human_num': 8}

# %%
from matplotlib.axes import Axes
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(30, 30))
ax.set_xlim(-6.5, 6.5) # 6
ax.set_ylim(-6.5, 6.5)
ax.axes.xaxis.set_visible(False)
ax.axes.yaxis.set_visible(False)
plt.ion()
plt.show()

# %%
env.render_axis = ax

# %%
observation = env.reset()
for _ in range(1000):
    action = env.action_space.sample()  # User-defined policy function
    observation, reward, terminated, truncated, info = env.step(action) 
    env.render()
    if terminated or truncated:
        observation, info = env.reset()
env.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [12], line 4
#       2 for _ in range(1000):
#       3     action = env.action_space.sample()  # User-defined policy function
# ----> 4     observation, reward, terminated, truncated, info = env.step(action)
#       5     env.render()
#       6     if terminated or truncated:
#
# File ~/CrowdNav_Prediction_AttnGraph/crowd_sim/envs/crowd_sim_var_num.py:391, in CrowdSimVarNum.step(self, action, update)
#     388     self.calc_human_future_traj(method='truth')
#     390 # compute reward and episode info
# --> 391 reward, done, episode_info = self.calc_reward(action, danger_zone='future')
#     394 # apply action and update all agents
#     395 self.robot.step(action)
#
# File ~/CrowdNav_Prediction_AttnGraph/crowd_sim/envs/crowd_sim_var_num.py:501, in CrowdSimVarNum.calc_reward(self, action, danger_zone)
#     498     min_danger_dist = 0
#     499 else:
#     500     # if the robot collides with future states, give it a collision penalty
# --> 501     relative_pos = self.human_future_traj[1:, :, :2] - np.array([self.robot.px, self.robot.py])
#     502     relative_dist = np.linalg.norm(relative_pos, axis=-1)
#     504     collision_idx = relative_dist < self.robot.radius + self.config.humans.radius  # [predict_steps, human_num]
#
# AttributeError: 'CrowdSimVarNum' object has no attribute 'human_future_traj'

# %%
env.action_space.sample()
# Out:
# array([ 1.7352986, -1.1975546], dtype=float32)
